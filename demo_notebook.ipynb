# %%
import polars as pl
import pymeasy as pm

# %%
rsa = pm.irsa(290000017, 2022, 12, "/data/mco", typi = 4)

# %%
rsa
# Out:
# {'rsa': shape: (141901, 89)
#  ┌───────────┬────────┬────────────┬────────┬─────┬──────┬──────┬─────┬─────────┐
#  │ nofiness  ┆ novrsa ┆ cle_rsa    ┆ novrss ┆ ... ┆ dr   ┆ ndas ┆ na  ┆ filler6 │
#  │ ---       ┆ ---    ┆ ---        ┆ ---    ┆     ┆ ---  ┆ ---  ┆ --- ┆ ---     │
#  │ str       ┆ str    ┆ str        ┆ str    ┆     ┆ str  ┆ i64  ┆ i64 ┆ str     │
#  ╞═══════════╪════════╪════════════╪════════╪═════╪══════╪══════╪═════╪═════════╡
#  │ 290000017 ┆ 227    ┆ 000000000x ┆ 121    ┆ ... ┆ D761 ┆ 10   ┆ 2   ┆         │
#  │ 290000017 ┆ 227    ┆ 000000000x ┆ 121    ┆ ... ┆      ┆ 113  ┆ 90  ┆         │
#  │ 290000017 ┆ 227    ┆ 000000000x ┆ 121    ┆ ... ┆      ┆ 73   ┆ 754 ┆         │
#  │ 290000017 ┆ 227    ┆ 000000000x ┆ 121    ┆ ... ┆      ┆ 15   ┆ 20  ┆         │
#  │ ...       ┆ ...    ┆ ...        ┆ ...    ┆ ... ┆ ...  ┆ ...  ┆ ... ┆ ...     │
#  │ 290000017 ┆ 227    ┆ 000xxxxxxx ┆ 121    ┆ ... ┆      ┆ 8    ┆ 28  ┆         │
# ...

# %%
rsa = pm.irsa(290000017, 2022, 12, "/data/mco", typi = 6)

# %%
rsa
# Out:
# {'rsa': shape: (141901, 94)
#  ┌───────────┬────────┬─────────────┬────────┬─────┬──────────┬─────────────┬───────────┬───────────┐
#  │ nofiness  ┆ novrsa ┆ cle_rsa     ┆ novrss ┆ ... ┆ stream_d ┆ stream_um   ┆ stream_dp ┆ stream_dr │
#  │ ---       ┆ ---    ┆ ---         ┆ ---    ┆     ┆ as       ┆ ---         ┆ um        ┆ um        │
#  │ str       ┆ str    ┆ str         ┆ str    ┆     ┆ ---      ┆ str         ┆ ---       ┆ ---       │
#  │           ┆        ┆             ┆        ┆     ┆ str      ┆             ┆ str       ┆ str       │
#  ╞═══════════╪════════╪═════════════╪════════╪═════╪══════════╪═════════════╪═══════════╪═══════════╡
#  │ 290000017 ┆ 227    ┆ 000000000x  ┆ 121    ┆ ... ┆ R13,     ┆ 28 M        ┆ Z515      ┆ D761      │
#  │           ┆        ┆             ┆        ┆     ┆ R4702,   ┆             ┆           ┆           │
#  │           ┆        ┆             ┆        ┆     ┆ K590,    ┆             ┆           ┆           │
# ...

# %%
rum = pm.irum(290000017, 2022, 12, "/data/mco", typi = 1)

# %%
rum
# Out:
# {'rum': shape: (156889, 43)
#  ┌────────┬────────┬────────┬───────┬─────┬─────────────────┬──────────────┬────────┬──────────────┐
#  │ noclas ┆ cdghm  ┆ noverg ┆ cderg ┆ ... ┆ categ_nb_interv ┆ adnp_75_plus ┆ zonres ┆ dureesejpart │
#  │ ---    ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---             ┆ ---          ┆ ---    ┆ ---          │
#  │ str    ┆ str    ┆ str    ┆ str   ┆     ┆ str             ┆ str          ┆ str    ┆ i64          │
#  ╞════════╪════════╪════════╪═══════╪═════╪═════════════════╪══════════════╪════════╪══════════════╡
#  │ 11     ┆ 01M192 ┆ 121    ┆ 000   ┆ ... ┆                 ┆              ┆        ┆ 6            │
#  │ 11     ┆ 01M192 ┆ 121    ┆ 000   ┆ ... ┆                 ┆              ┆        ┆ 5            │
#  │ 11     ┆ 01M192 ┆ 121    ┆ 000   ┆ ... ┆                 ┆              ┆        ┆ 10           │
#  │ 11     ┆ 01M192 ┆ 121    ┆ 000   ┆ ... ┆                 ┆              ┆        ┆ 20           │
# ...

# %%
ano = pm.iano_mco(290000017, 2022, 12, "/data/mco", typano = "out")
